# %%
import copy
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import scipy
import time
import glob
import xarray as xr
import cartopy.crs as ccrs

from pandas import DataFrame
from properscoring import crps_ensemble
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from ensemble_evaluation_functions import *

# %%
def plot_metric(metric,lat,lon,name_metric,ideal_val,cmap='jet',
                vmin=None,vmax=None,units=None,cbar_label=None,path_save=None):
    # Set up the projection and plot the data
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    p = ax.pcolormesh(lon, lat, metric, cmap=cmap, transform=ccrs.PlateCarree(), vmin=vmin, vmax=vmax)

    # Set up the colorbar
    if cbar_label is not None:
        cbar_label = f"({var.units})"
    cbar = plt.colorbar(p, ax=ax, orientation='horizontal', shrink=0.5, pad=0.1)
    cbar.ax.set_xlabel(cbar_label)

    # Add coastlines and gridlines
    ax.coastlines()
    ax.gridlines(draw_labels=True)

    # Set the title
    ax.set_title(f'{name_metric}\nAverage: {str(np.round(np.mean(metric),2))}\n(Ideal value: {ideal_val})', fontsize=14)
    if path_save == None:
        plt.show()
    else:
        plt.savefig(path_save,bbox_inches='tight')
    # return fig

# %%
path_base = '/glade/scratch/molina/'

# %%
for week in [3,4]:
    print(week)
    folders_ensembles = np.sort(glob.glob(f'{path_base}cesm_prsfc_week{week}_m*/'))
    list_arrays = []
    for folder in folders_ensembles:
        # print(folder)
        list_files = np.sort(glob.glob(f'{folder}*.nc'))
        dataset_member = xr.open_mfdataset(list_files,combine='nested',concat_dim="time")
        dataarray_member = dataset_member.pr_sfc[:,0,0,:,:].drop_vars(['sample','ens'])
        list_arrays.append(dataarray_member)
        
    ensemble = xr.concat(list_arrays,dim='member').transpose('time','lat','lon','member')
    ensemble = ensemble.load()

    files_era = np.sort(glob.glob(f'{path_base}era5_prsfc_week{week}/*.nc'))
    dataset_era = xr.open_mfdataset(list_files,combine='nested',concat_dim="time")
    dataarray_era = dataset_member.pr_sfc[:,0,0,:,:].drop_vars(['sample','ens'])
    dataarray_era = dataarray_era.load()
    
    ### Compute metrics
    
    ssrel,ssrat = get_spread_skill_2d(dataarray_era.values,ensemble.values)
    mf,di = get_discard_skill_2d(dataarray_era.values,ensemble.values)
    pitd = get_pitd_2d(dataarray_era.values,ensemble.values)
    crps = get_crps_2d(dataarray_era.values,ensemble.values)
    # ign = get_ign_2d(dataarray_era.values,ensemble.values)
    
    metrics = [ssrel, ssrat, mf, di, pitd, crps]
    names_metrics = ['Spread-skill reliability',
             'Spread-skill ratio',
             'Monotonicity fraction',
             'Discard improvement',
             'Probability integral transform deviation',
             'Continuous ranked probability score'
                    ]
    short_names_metrics = ['ssrel', 'ssrat', 'mf', 'di', 'pitd', 'crps']
    ideal_val_metric = ['0', '1', '1', 'Higher is better', '0', '0']
    
    lat = dataset_era.lat
    lon = dataset_era.lon
    
    for i in range(len(metrics)):
        np.save(f'OutputEvaluation/eval_cesm_prsfc_week{week}_{short_names_metrics[i]}.npy',(lat,lon,metrics[i]))
        plot_metric(metrics[i],lat,lon,names_metrics[i],ideal_val_metric[i],
                    path_save = f'Figures/eval_cesm_prsfc_week{week}_{short_names_metrics[i]}.png')
# Out:
# 3
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 12
#       9     dataarray_member = dataset_member.pr_sfc[:,0,0,:,:].drop_vars(['sample','ens'])
#      10     list_arrays.append(dataarray_member)
# ---> 12 ensemble = xr.concat(list_arrays,dim='member').transpose('time','lat','lon','member')
#      13 ensemble = ensemble.load()
#      15 files_era = np.sort(glob.glob(f'{path_base}era5_prsfc_week{week}/*.nc'))
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/concat.py:231, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     226     raise ValueError(
#     227         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     228     )
#     230 if isinstance(first_obj, DataArray):
# --> 231     return _dataarray_concat(
#     232         objs,
#     233         dim=dim,
#     234         data_vars=data_vars,
#     235         coords=coords,
#     236         compat=compat,
#     237         positions=positions,
#     238         fill_value=fill_value,
#     239         join=join,
#     240         combine_attrs=combine_attrs,
#     241     )
#     242 elif isinstance(first_obj, Dataset):
#     243     return _dataset_concat(
#     244         objs,
#     245         dim=dim,
#    (...)
#     252         combine_attrs=combine_attrs,
#     253     )
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/concat.py:657, in _dataarray_concat(arrays, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     654             arr = cast(T_DataArray, arr.rename(name))
#     655     datasets.append(arr._to_temp_dataset())
# --> 657 ds = _dataset_concat(
#     658     datasets,
#     659     dim,
#     660     data_vars,
#     661     coords,
#     662     compat,
#     663     positions,
#     664     fill_value=fill_value,
#     665     join=join,
#     666     combine_attrs=combine_attrs,
#     667 )
#     669 merged_attrs = merge_attrs([da.attrs for da in arrays], combine_attrs)
#     671 result = arrays[0]._from_temp_dataset(ds, name)
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/concat.py:466, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     463 # Make sure we're working on a copy (we'll be loading variables)
#     464 datasets = [ds.copy() for ds in datasets]
#     465 datasets = list(
# --> 466     align(*datasets, join=join, copy=False, exclude=[dim], fill_value=fill_value)
#     467 )
#     469 dim_coords, dims_sizes, coord_names, data_names = _parse_datasets(datasets)
#     470 dim_names = set(dim_coords)
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/alignment.py:764, in align(join, copy, indexes, exclude, fill_value, *objects)
#     568 """
#     569 Given any number of Dataset and/or DataArray objects, returns new
#     570 objects with aligned indexes and dimension sizes.
#    (...)
#     754
#     755 """
#     756 aligner = Aligner(
#     757     objects,
#     758     join=join,
#    (...)
#     762     fill_value=fill_value,
#     763 )
# --> 764 aligner.align()
#     765 return aligner.results
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/alignment.py:552, in Aligner.align(self)
#     550 self.assert_no_index_conflict()
#     551 self.align_indexes()
# --> 552 self.assert_unindexed_dim_sizes_equal()
#     554 if self.join == "override":
#     555     self.override_indexes()
#
# File /glade/work/jhayron/conda-envs/weather_regimes/lib/python3.9/site-packages/xarray/core/alignment.py:452, in Aligner.assert_unindexed_dim_sizes_equal(self)
#     450     add_err_msg = ""
#     451 if len(sizes) > 1:
# --> 452     raise ValueError(
#     453         f"cannot reindex or align along dimension {dim!r} "
#     454         f"because of conflicting dimension sizes: {sizes!r}" + add_err_msg
#     455     )
#
# ValueError: cannot reindex or align along dimension 'time' because of conflicting dimension sizes: {1195, 966}
